# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h2> <font color='aquamarine'>Cleaning the Dataset </font></h2>

# %%
ds_houses = pd.read_csv('house_prices.csv')

# %%
ds_houses.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
ds_houses.drop(['id', 'date', 'sqft_living15', 'sqft_lot15'], axis = 1, inplace=True)

# %%
ds_train = ds_houses.iloc[0:15129,:]
ds_test = ds_houses.iloc[15129:,:]

# %%
ds_test.head()
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 15129  937750.0         4       2.75         2580      3560     1.5
# 15130  725126.0         4       2.50         3200     12369     2.0
# 15131  135000.0         3       1.00          840      3000     1.0
# 15132  635000.0         4       2.50         2970      7961     1.0
# 15133  245500.0         2       1.00          790      7500     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 15129           0     0          5      7        1710            870
# 15130           0     0          3     10        3200              0
# 15131           0     0          3      5         840              0
# 15132           0     0          3      8        2020            950
# 15133           0     0          3      6         790              0
#
#        yr_built  yr_renovated  zipcode      lat     long
# 15129      1917             0    98115  47.6753 -122.304
# 15130      1998             0    98059  47.5273 -122.143
# 15131      1943             0    98178  47.4940 -122.275
# 15132      1969             0    98125  47.7118 -122.290
# 15133      1950             0    98011  47.7644 -122.198

# %% [markdown]
# <p><font color='#50C878' size=5><b>Train set has to be a pandas ds (csv file), the test data set has a numpy type</b></font></p>

# %%
x_test = ds_test.iloc[:,1:17].values
y_test = ds_test.iloc[:,0].values

# %%
ds_train.to_csv('ds_train_xboost.csv', header = False, index = False)
ds_test.to_csv('ds_test_xboost.csv', header = False, index = False)

# %% [markdown]
# <h2> <font color='aquamarine'>Sagemaker setup </font></h2>

# %%
import sagemaker
import boto3

# %%
session = sagemaker.Session()
bucket = 'rogerio-curso-aws'
sub_folder_models = 'models/house_prices/xgboost'
sub_folder_dataset = 'datasets/house_prices'
key_train = 'house_train_xgboost'
key_test = 'house_test_xgboost'
role = sagemaker.get_execution_role()
s3_train = f's3://{bucket}/{sub_folder_dataset}/train/{key_train}'
s3_test = f's3://{bucket}/{sub_folder_dataset}/test/{key_test}'
output_path = f's3://{bucket}/{sub_folder_models}/output'

# %%
import os

# %%
with open('ds_train_xboost.csv', 'rb') as f:
    boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(sub_folder_dataset,'train',key_train)).upload_fileobj(f)

# %%
with open('ds_test_xboost.csv', 'rb') as f:
    boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(sub_folder_dataset,'test',key_test)).upload_fileobj(f)

# %% [markdown]
# <h2> <font color='aquamarine'>XGBoost training </font></h2>

# %%
container = sagemaker.image_uris.retrieve(framework='xgboost', region = boto3.Session().region_name, version = 'latest')
xgboost = sagemaker.estimator.Estimator(image_uri = container,
                                        role = role,
                                        instance_count=1,
                                        instance_type='ml.m5.xlarge',
                                        output_path=output_path,
                                        sagemaker_session=session
                                       )

# %%
xgboost.set_hyperparameters(num_round = 100)

# %%
train_input = sagemaker.inputs.TrainingInput(s3_data = s3_train, content_type='csv', s3_data_type='S3Prefix')
test_input = sagemaker.inputs.TrainingInput(s3_data = s3_test, content_type='csv', s3_data_type='S3Prefix')
data_channels = {'train': train_input,'validation': test_input}

# %%
xgboost.fit(data_channels)
# Out:
# 2022-09-29 18:31:08 Starting - Starting the training job...ProfilerReport-1664476268: InProgress
# ...
# 2022-09-29 18:32:02 Starting - Preparing the instances for training.........
# 2022-09-29 18:33:33 Downloading - Downloading input data......
# 2022-09-29 18:34:33 Training - Downloading the training image..Arguments: train
# [2022-09-29:18:34:49:INFO] Running standalone xgboost training.
# [2022-09-29:18:34:49:INFO] File size need to be processed in the node: 1.55mb. Available memory size in the node: 8448.76mb
# [2022-09-29:18:34:49:INFO] Determined delimiter of CSV input is ','
# [18:34:49] S3DistributionType set as FullyReplicated
# [18:34:49] 15129x16 matrix with 242064 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=6
# [51]#011train-rmse:70255.8#011validation-rmse:123163
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [52]#011train-rmse:69727.2#011validation-rmse:123042
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [53]#011train-rmse:69440.7#011validation-rmse:123111
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=6
# [54]#011train-rmse:68825.1#011validation-rmse:123141
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [55]#011train-rmse:68565.3#011validation-rmse:123090
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [56]#011train-rmse:68338.4#011validation-rmse:123152
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [57]#011train-rmse:67920.7#011validation-rmse:123112
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [58]#011train-rmse:67691.5#011validation-rmse:123068
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [59]#011train-rmse:67354.8#011validation-rmse:123099
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [60]#011train-rmse:67214.5#011validation-rmse:123082
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [61]#011train-rmse:66841.3#011validation-rmse:123000
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [62]#011train-rmse:66220.1#011validation-rmse:122741
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [63]#011train-rmse:65776.9#011validation-rmse:122745
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=6
# [64]#011train-rmse:65230#011validation-rmse:122510
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [65]#011train-rmse:64952.9#011validation-rmse:122614
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [66]#011train-rmse:64498.1#011validation-rmse:122433
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [67]#011train-rmse:64177.6#011validation-rmse:122545
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=6
# [68]#011train-rmse:63860.8#011validation-rmse:122529
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=6
# [69]#011train-rmse:63643.2#011validation-rmse:122515
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [70]#011train-rmse:63290.7#011validation-rmse:122466
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=6
# [71]#011train-rmse:62927.3#011validation-rmse:122467
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [72]#011train-rmse:62666.3#011validation-rmse:122420
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [73]#011train-rmse:62308.9#011validation-rmse:122362
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=6
# [74]#011train-rmse:62192.3#011validation-rmse:122376
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [75]#011train-rmse:62037.5#011validation-rmse:122359
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [76]#011train-rmse:61797.9#011validation-rmse:122453
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=6
# [77]#011train-rmse:61252.2#011validation-rmse:122482
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=6
# [78]#011train-rmse:60662.8#011validation-rmse:122460
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [79]#011train-rmse:60478.4#011validation-rmse:122408
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=6
# [80]#011train-rmse:60104.5#011validation-rmse:122487
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [81]#011train-rmse:60042.5#011validation-rmse:122457
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [82]#011train-rmse:59856.7#011validation-rmse:122461
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [83]#011train-rmse:59576.2#011validation-rmse:122424
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=6
# [84]#011train-rmse:59223.4#011validation-rmse:122388
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [85]#011train-rmse:58942.1#011validation-rmse:122293
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [86]#011train-rmse:58657.7#011validation-rmse:122211
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [87]#011train-rmse:58411.9#011validation-rmse:122234
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [88]#011train-rmse:58308.5#011validation-rmse:122246
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [89]#011train-rmse:58279.1#011validation-rmse:122253
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [90]#011train-rmse:58107.2#011validation-rmse:122232
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [91]#011train-rmse:57885.6#011validation-rmse:122227
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [92]#011train-rmse:57525.8#011validation-rmse:122237
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [93]#011train-rmse:57313.3#011validation-rmse:122250
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [94]#011train-rmse:56991.2#011validation-rmse:122280
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [95]#011train-rmse:56903.8#011validation-rmse:122292
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [96]#011train-rmse:56724.3#011validation-rmse:122300
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [97]#011train-rmse:56407.2#011validation-rmse:122112
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [98]#011train-rmse:56064.4#011validation-rmse:122013
# [18:34:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [99]#011train-rmse:55896.7#011validation-rmse:121962
#
# 2022-09-29 18:35:08 Uploading - Uploading generated training model
# 2022-09-29 18:35:08 Completed - Training job completed
# Training seconds: 98
# Billable seconds: 98

# %% [markdown]
# <h1><font color='aquamarine' size = 5>Deploy, preditions, evaluating</font></h1>

# %%
xbooster_regressor = xgboost.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# ------!

# %%
from sagemaker.serializers import CSVSerializer
xbooster_regressor.serializer = CSVSerializer()

# %%
pred = xbooster_regressor.predict(x_test).decode('utf-8').split(',')
pred = np.array(pred).astype(np.float32)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mae = mean_absolute_error(y_test, pred)
msae = mean_absolute_error(y_test, pred)
rmse = np.sqrt(mean_absolute_error(y_test, pred))

# %%
print(f' MAE: {mae.round(2)}\n MSAE: {msae.round(2)}\n RMSE: {rmse.round(2)}')
# Out:
#  MAE: 69311.55
#  MSAE: 69311.55
#  RMSE: 263.27

# %% [markdown]
# <h1><font color='aquamarine' size = 5> Tuning </font></h1>

# %%
tuning_job_config = {
     "ParameterRanges": {
      "CategoricalParameterRanges": [],
      "ContinuousParameterRanges": [
        {
          "MaxValue": "1",
          "MinValue": "0",
          "Name": "eta"
        },
        {
          "MaxValue": "2",
          "MinValue": "0",
          "Name": "alpha"
        },
        {
          "MaxValue": "10",
          "MinValue": "1",
          "Name": "min_child_weight"
        }
      ],
      "IntegerParameterRanges": [
        {
          "MaxValue": "10",
          "MinValue": "1",
          "Name": "max_depth"
        }
      ],
      "IntegerParameterRanges": [
        {
          "MaxValue": "300",
          "MinValue": "50",
          "Name": "num_round"
        }
      ]
    },
    "ResourceLimits": {
      "MaxNumberOfTrainingJobs": 5,
      "MaxParallelTrainingJobs": 3
    },
    "Strategy": "Bayesian",
    "HyperParameterTuningJobObjective": {
      "MetricName": "validation:rmse",
      "Type": "Minimize"
    }
  }

# %%
training_job_definition = {
    "AlgorithmSpecification": {
      "TrainingImage": container,
      "TrainingInputMode": "File"
    },
    "InputDataConfig": [
      {
        "ChannelName": "train",
        "CompressionType": "None",
        "ContentType": "csv",
        "DataSource": {
          "S3DataSource": {
            "S3DataDistributionType": "FullyReplicated",
            "S3DataType": "S3Prefix",
            "S3Uri": s3_train
          }
        }
      },
      {
        "ChannelName": "validation",
        "CompressionType": "None",
        "ContentType": "csv",
        "DataSource": {
          "S3DataSource": {
            "S3DataDistributionType": "FullyReplicated",
            "S3DataType": "S3Prefix",
            "S3Uri": s3_test
          }
        }
      }
    ],
    "OutputDataConfig": {
      "S3OutputPath": "s3://{}/{}/output".format(bucket,sub_folder_models)
    },
    "ResourceConfig": {
      "InstanceCount": 2,
      "InstanceType": "ml.m5.xlarge",
      "VolumeSizeInGB": 10
    },
    "RoleArn": role,
    "StaticHyperParameters": {
      "eval_metric": "rmse",
      "objective": "reg:linear",
      "rate_drop": "0.3",
      "tweedie_variance_power": "1.4"
    },
   
    "StoppingCondition": {
      "MaxRuntimeInSeconds": 43200
    }
}

# %%
smclient = boto3.client('sagemaker')
smclient.create_hyper_parameter_tuning_job(HyperParameterTuningJobName = 'xgboosttuninghouses',
                                            HyperParameterTuningJobConfig = tuning_job_config,
                                            TrainingJobDefinition = training_job_definition
                                          )
# Out:
# {'HyperParameterTuningJobArn': 'arn:aws:sagemaker:sa-east-1:890895794940:hyper-parameter-tuning-job/xgboosttuninghouses',
#  'ResponseMetadata': {'RequestId': '2442d862-27d5-4e7c-84fa-185bb00bcfe1',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '2442d862-27d5-4e7c-84fa-185bb00bcfe1',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '120',
#    'date': 'Thu, 29 Sep 2022 19:58:26 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# <h3><font color='aquamarine' style ='bold'> Hyperparameters results</font></h3>
#
# <p>Key	Value<br>
# _tuning_objective_metric	validation:rmse<br>
# alpha	1.7114218618998898<br>
# eta	0.09874686146818112<br>
# eval_metric	rmse<br>
# min_child_weight	1.8351150086549781<br>
# num_round	204<br>
# objective	reg:linear<br>
# rate_drop	0.3<br>
# tweedie_variance_power	1.4</p>
